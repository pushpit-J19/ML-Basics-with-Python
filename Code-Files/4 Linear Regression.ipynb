# %% [markdown]
# ## LINEAR REGRESSION

# %% [markdown]
# Regression with continuous target value present
#
# Eqn of line : y = mx + c
#
# The line which fits the graph best is considered.
#
# Say a relation between area and price. Then P = mA + c  , we can get approx. price for this area. This predicted accuracy depends on fitting and data. Losses :-
#
# Manhattan distance = | yp – ya |
#
#   Not very accurate results but gives realistic. 4 and 9 difference not as much visible tho it may be very large logically. This is not taken as its graph is not differentiable and not penalizing the values that are too far
#
# Square root distance = | yp – ya |^2
#
#   Really high for points that are far, gives the results accurately. Accurate as difference between 4 and 9 very clearly told.
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Loss or cost function = loss sum / no of observations
#
# Sqr root loss will be a parabola/bell shaped curve c = ( yp – ya )^2
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# We want to minimize our loss. To best fit. M and C are varying.
#
# Cost J = I/M SUM(mx+c-ya)^2
#
# If c=0, the best fit line will have minimum J at say mi for various m (10degree, 30, 45, 60 ,75,90) in either directions the J will only increase, so J and m(slope) are related parabolically. Right side positive slope, left side negative slope. This is called “gradient decent” used to minimize cost
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Yp = mx+c		hypothesis
#
# J = sum( Yp – Ya)^2 / Mn
#
# J = sum( mx+c – Ya)^2 / Mn	loss/cost function
#
# To minimize cost function, using gradient decent
#
# Hypothesis -> Cost to be minimized  to predict the outcome
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# The decent is don’t at some interval or by some factor in every iteration, this is called alpha “the learning rate”. At first take big steps, then step size decreases and lastly becomes infitly small.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Case 1 : alpha is v small - Will take a lottt of time but will definitely reach small
#
# Case 2 : alpha is big : big jumps so goes to / overshoots to the other side
#
# So carefully need to choose alpha generally  between [0.01 , 0.1]
#
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---
#
#
#
# Updation of c and m by these two equations and partial derivatives of the relation
#
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import make_regression, make_classification, make_blobs, make_moons

x, y = make_regression (n_samples=4000, n_features=1, n_informative=1, noise=10)

# %%
plt.scatter(x,y)
plt.show()

# %%
x.shape, type(x)
# Out:
# ((4000, 1), numpy.ndarray)

# %%
def run(x, y) :
  num_iterations = 200
  learn_rate = 0.01
  #learn_rate = 0.001

  m, c = gradient_decent(x,y,num_iterations, learn_rate)
  return m,c

# %%
def gradient_decent(x, y, num_iterations, learn_rate): 
  m, c = 0, 0
  for i in range (num_iterations) :
    m, c = step_gd (x, y, m, c, learn_rate)
    
  return m,c

# %%
def step_gd(x, y, m, c, learn_rate):
  m_slope, c_slope = 0, 0
  N = x.shape[0]
  
  for i in range (N):
    X = x[i]
    Y = y[i] 
    m_slope += (2/N)*((X*m + c - Y)*X) # the m = derivative ewn from imgs
    c_slope += (2/N)*(X*m + c - Y)
    
  new_m = m - learn_rate * m_slope
  new_c = c - learn_rate * c_slope
  return new_m, new_c

# %%
m, c = run(x, y)
m, c
# Out:
# (array([60.47262301]), array([0.21778181]))

# %%
pred_y = []
for i in range(x.shape[0]):
  temp = m*x[i] + c
  pred_y.append(temp)

# %%
# 5 iterations
plt.scatter(x, y)
plt.plot(x, pred_y, c="r")
plt.show()

# %% [markdown]
# Very bad fitting for 5 iterations
#
# ![image.png](data:image/png;base64,...)

# %%
# 10 iterations
plt.scatter(x, y)
plt.plot(x, pred_y, c="r")
plt.show()

# %%
# 100 iterations
plt.scatter(x, y)
plt.plot(x, pred_y, c="r")
plt.show()

# %% [markdown]
# line moving in opp direction
#
# so decreasing learning rate to 0.001
#
# and sign problem was also there in calculating slope

# %%
plt.scatter(x, y)
plt.plot(x, pred_y, c="r")
plt.show()

# %%
# 500 iterations and 0.001 learning rate
plt.scatter(x, y)
plt.plot(x, pred_y, c="r")
plt.show()

# %%
# 5 , 0.001
plt.scatter(x, y)
plt.plot(x, pred_y, c="r")
plt.show()

# %%
# 10, 0.001
plt.scatter(x, y)
plt.plot(x, pred_y, c="r")
plt.show()

# %%
# 10 , 0.01
plt.scatter(x, y)
plt.plot(x, pred_y, c="r")
plt.show()

# %%
# 100 , 0.01
plt.scatter(x, y)
plt.plot(x, pred_y, c="r")
plt.show()

# %%
# 200 , 0.01
plt.scatter(x, y)
plt.plot(x, pred_y, c="r")
plt.show()
