# %% [markdown]
# https://www.kaggle.com/vikrishnan/boston-house-prices
#
# https://archive.ics.uci.edu/ml/machine-learning-databases/housing/
#
# Housing_names has all the data about dataset in second link

# %%
! pip install -q kaggle

from google.colab import files

files.upload()
# Out:
#      <input type="file" id="files-e2e1f4d0-38dd-4477-a1ce-d8c7a63912af" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e2e1f4d0-38dd-4477-a1ce-d8c7a63912af">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"pushpit19jain","key":"b7c5f470a3b48f2bdcf9577295307ba6"}'}

# %%
! mkdir ~/.kaggle

! cp kaggle.json ~/.kaggle/

! chmod 600 ~/.kaggle/kaggle.json
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists

# %%
! kaggle datasets download -d vikrishnan/boston-house-prices
# Out:
# boston-house-prices.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
! unzip /content/boston-house-prices.zip
# Out:
# Archive:  /content/boston-house-prices.zip
#   inflating: housing.csv

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### GENERALIZED FORM FOR MULTIVAR
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Normalization scaling is important so that in case of large difference in ranges of x1 and x2 features, dont cause x2 (x1<<x2) to overpower the target H

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression

# %%
headings = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD','TAX', 'PTRATIO','B','LSTAT','MEDV']
df = pd.read_fwf("/content/housing.data", names=headings)

# %%
df.columns, df.shape
# this time multiple attributes
# Out:
# (Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#         'PTRATIO', 'B', 'LSTAT', 'MEDV'],
#        dtype='object'), (506, 14))

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX  ...    TAX  PTRATIO       B  LSTAT  MEDV
# 0  0.00632  18.0   2.31     0  0.538  ...  296.0     15.3  396.90   4.98  24.0
# 1  0.02731   0.0   7.07     0  0.469  ...  242.0     17.8  396.90   9.14  21.6
# 2  0.02729   0.0   7.07     0  0.469  ...  242.0     17.8  392.83   4.03  34.7
# 3  0.03237   0.0   2.18     0  0.458  ...  222.0     18.7  394.63   2.94  33.4
# 4  0.06905   0.0   2.18     0  0.458  ...  222.0     18.7  396.90   5.33  36.2
#
# [5 rows x 14 columns]

# %%
df.info()
# all int float, so no need to do label encoding
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    int64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %%
df.describe()
# see mean varies from 0.06 to 22
# Out:
#              CRIM          ZN       INDUS  ...           B       LSTAT        MEDV
# count  506.000000  506.000000  506.000000  ...  506.000000  506.000000  506.000000
# mean     1.716290   11.363636   11.136779  ...  356.674032   12.653063   22.532806
# std      2.653510   23.322453    6.860353  ...   91.294864    7.141062    9.197104
# min      0.006320    0.000000    0.460000  ...    0.320000    1.730000    5.000000
# 25%      0.081900    0.000000    5.190000  ...  375.377500    6.950000   17.025000
# 50%      0.250895    0.000000    9.690000  ...  391.440000   11.360000   21.200000
# 75%      2.326718   12.500000   18.100000  ...  396.225000   16.955000   25.000000
# max      9.966540  100.000000   27.740000  ...  396.900000   37.970000   50.000000
#
# [8 rows x 14 columns]

# %%
df.corr()
# Out:
#              CRIM        ZN     INDUS  ...         B     LSTAT      MEDV
# CRIM     1.000000 -0.300774  0.590822  ... -0.377013  0.481907 -0.362077
# ZN      -0.300774  1.000000 -0.533828  ...  0.175520 -0.412995  0.360445
# INDUS    0.590822 -0.533828  1.000000  ... -0.356977  0.603800 -0.483725
# CHAS     0.013922 -0.042697  0.062938  ...  0.048788 -0.053929  0.175260
# NOX      0.634679 -0.516604  0.763651  ... -0.380051  0.590879 -0.427321
# RM      -0.190197  0.311991 -0.391676  ...  0.128069 -0.613808  0.695360
# AGE      0.482013 -0.569537  0.644779  ... -0.273534  0.602339 -0.376955
# DIS     -0.495148  0.566660 -0.678498  ...  0.293621 -0.479158  0.264325
# RAD     -0.088451 -0.119290 -0.087615  ...  0.040705 -0.069828  0.113519
# TAX      0.793392 -0.314563  0.720760  ... -0.441808  0.543993 -0.468536
# PTRATIO  0.362615 -0.391679  0.383248  ... -0.177383  0.374044 -0.507787
# B       -0.377013  0.175520 -0.356977  ...  1.000000 -0.366087  0.333461
# ...

# %%
plt.figure(figsize=(15,8)) # increasing size
sns.heatmap(df.corr(), annot=True) #, cmap="gray")
plt.show()

# %% [markdown]
# target is MEDV, so seeing the correlation with other columns

# %%
sns.pairplot(df)
plt.show()
# graphs

# %%
df.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
# no need to change as no na values still code for replacing all with mean
for col in df.columns :
  df[col].fillna(df[col].mean(), inplace=True)

# %%
xtrain = df.iloc[:, :13].values
ytrain = df.iloc[:, 13].values
xtrain.shape, ytrain.shape
# Out:
# ((506, 13), (506,))

# %%
xtrain[0], ytrain[0]
# Out:
# (array([6.320e-03, 1.800e+01, 2.310e+00, 0.000e+00, 5.380e-01, 6.575e+00,
#         6.520e+01, 4.090e+00, 1.000e+00, 2.960e+02, 1.530e+01, 3.969e+02,
#         4.980e+00]), 24.0)

# %%
sc = StandardScaler ()
xtrain = sc.fit_transform(xtrain)

# %%
xtrain[0]
# Out:
# array([-0.64505599,  0.28482986, -1.2879095 , -0.27259857, -0.14421743,
#         0.41367189, -0.12001342,  0.19711129, -2.35350941, -0.66660821,
#        -1.45900038,  0.44105193, -1.0755623 ])

# %%
# from sklearn.linear_model import LinearRegression
regmodel = LinearRegression()
regmodel.fit(xtrain, ytrain)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
ypred = regmodel.predict(xtrain)

# %%
# SCORE
# RMSE = ROOT( sum((pred - ya)**2) / n )
# root mean squared error
regmodel.score(xtrain, ytrain)
# Out:
# 0.7198065414937173
